# %%
a = open("xxd").readlines()
a
# Out:
# ['0000000000000db94280000000000000\n',
#  '000000000000050f0000000000000000\n',
#  '000000000000040b0000000000000000\n',
#  '0000000000000e050000000000000000\n',
#  '0000000000000b020000000000000000\n',
#  '00000000000001000000000000000000\n',
#  '00000000000000000000000000000000\n',
#  '000000000000053b68d0000000000000\n',
#  '00000000000000000030000000000000\n',
#  '00000000000000000090000000000000\n',
#  '00000000000000000070000000000000\n',
#  '000000000000000000c0000000000000\n',
#  '00000000000000000050000000000000\n',
#  '00000000000000000000000000000000\n',
#  '00000000000000022420000000000000\n',
#  '00000000000000a0f000000000000000\n',
#  '0000000000000400a000000000000000\n',
#  '0000000000000a009000000000000000\n',
#  '0000000000000040c000000000000000\n',
#  '000000000000000bd870000000000000\n',
#  '00000000000000000000000000000000\n',
#  '000000000000001f6900000000000000\n',
#  '00000000000009000040000000000000\n',
#  '000000000000090000e0000000000000\n',
# ...

# %%
import matplotlib.pyplot as pt
import numpy as np
the_x = []
the_y = []
u = len(a)
v = len(a[1])

for x in range(len(a)):
    a = ""
    for y in range(len(a[x])-2):
        if a[x][y] != "0":
            the_x.append(x)
            the_y.append(-y)


#pt.scatter(the_x,the_y)
#pt.show()
